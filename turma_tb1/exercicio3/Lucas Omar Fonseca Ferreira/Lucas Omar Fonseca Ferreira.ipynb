# %%
1. 
    1.1 x>=y
        x y x>=y
        1 1  V
        1 0  V
        0 1  F
        0 0  V
        
    1.2 x<=y
    x y x<=y
        1 1  V
        1 0  F
        0 1  V
        0 0  V
        
    1.3 x!=y
    x y x!=y
        1 1  F
        1 0  V
        0 1  V
        0 0  F
        
    1.4 x>=0 and x<=float("inf")
    x x>0 x<=float("inf")
    1  V      V
    0  F      V
    
    1.5 x<=0 and y<=0
    x y x<=0 y<=0
    1 1  F    F
    1 0  F    V
    0 1  V    F
    0 0  V    V
    
    1.6 x>0 and y<0
    x y x>0 y<0
    1 1  V   F
    1 0  V   F
    0 1  F   F
    0 0  F   F
    
2.
Tabelas acima

3.
     .1 A B XOR
        V V F
        V F V
        F V V
        F F F
    
     .2 (not A and B) or (A and not B)

4.

        A B XOR
        V V  F
        V F  V
        F V  V
        F F  F
        
        A B  A ↔ B
        V V    V
        V F    F
        F V    F
        F F    V
        
5.

5.1. ¬ x ≤ y.
    x > y
    
5.2. ¬ x > y.
    x <= y
    
5.3. x ≥ y ∧ x < y.
    x >= y and x < y
    
5.4. x ≤ y ∨ x > y.
    x <= y or x > y

5.5. 0 ≤ x ≤ 10.
    0 <= x and x <= 10

5.6. ¬(a ∨ ¬b).
    A B A or ¬B ¬(a ∨ ¬b)
    V V   V        F
    V F   V        F
    F V   F        V
    F F   V        F
not A and B

5.7. ¬a → b.
A B a → b ¬a → b A ou B
V V  V      V      V
V F  F      V      V
F V  V      V      V
F F  V      F      F
A or B

5.8. ¬(a → b).
A B a → b ¬(a → b) a and not b
V V   V      F      F 
V F   F      V      V
F V   V      F      F
F F   V      F      F
A and not B

5.9. ¬(¬ a ∧ ¬ b).
    A B ¬a ∧ ¬b ¬(¬a ∧ ¬b)
    V V   F          V
    V F   F          V
    F V   F          V
    F F   V          F
A or B
6.
Tabelas feitas no exercício 5
7.
5.7 e 5.9

8.
A negação do E é o OU das negações
¬(A and B)
A B   A and B not(A and B)
V V     V         F
V F     F         V
F V     F         V
F F     F         V
(¬A or ¬B)
A B ¬A or ¬B
V V    F
V F    V
F V    V
F F    V

A negação do OU é o E das negações
¬(A or B)
A B  A or B  ¬(A or B)
V V    V         F
V F    V         F
F V    V         F
F F    F         V
(¬A and ¬B)
A B  ¬A and ¬B
V V     F
V F     F
F V     F
F F     V
# Out:
#   File "<ipython-input-1-5269733d8aa6>", line 2
#     1.1 x>=y
#     ^
# IndentationError: unexpected indent
