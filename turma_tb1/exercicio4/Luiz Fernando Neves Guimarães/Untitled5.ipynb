# %%
## Questão 1
a = int(input("Primeiro Valor"))
b = int(input("Segundo Valor"))
if a > b:
    print("O primeiro valor é o maior")
if a < b:
    print("O segundo valor é o maior")
if a == b:
    print("Os números têm o mesmo valor")
    
## Questão 2
## No programa 1 não há problemas em digitar valores negativos.
## No programa 2, ele aceita números negativos, mas não deveria aceitar

idade = int(input("Digite a idade do seu carro: "))
if idade >0 and idade <=3:
    print("Seu carro é novo")
if idade > 3:
    print("Seu carro é velho")
    
## Questão 3
salario = float(input("Valor do salário a ser calculado"))
if salario < 1500:
    print("O valor do salário não necessita de dedução de imposto")
if salario >= 1500 and salario < 3000:
    print("O valor do imposto é R$100.00")
if salario >= 3000 and salario < 5000:
    print("O valor do imposto é R$400.00")
if salario = 5000:
    print("O valor do imposto é R$1100.00")
    
## Questão 4

categoria = int(input("Digite a categoria: "))
if categoria == 1:
    preço = 10
elif categoria == 2:
    preço = 18
elif categoria == 3:
    preço = 23
elif categoria == 4:
    preço = 26
elif categoria == 5:
    preço = 31
else:
    print("Categoria inválida! Digite um valor entre 1 e 5!")
print:("O preço do produto é R$%6.2f"%preço)

## Questão 5
a = int(input("Entre com o primeiro número inteiro"))
b = int(input("Entre com o segundo número inteiro"))
c = int(input("Entre com o terceiro número inteiro"))
if a < b and a < c:
    print("O primeiro número é o menor")
if b < a and b < c:
    print("O segundo número é o menor")
if c < a and c < b:
    print("O terceiro número é o menor")

## Questão 6
a = int(input("Entre com o primeiro número inteiro"))
b = int(input("Entre com o segundo número inteiro"))
c = int(input("Entre com o terceiro número inteiro"))
resto_a = a % 2
resto_b = b % 2
resto_c = c % 2
if resto_a == 1 and a > b and a > c:
    print("O primeiro número é o maior número ímpar")
if resto_b == 1 and b > a and b > c:
    print("O segundo número é o maior número ímpar")
if resto_c == 1 and c > a and c > b:
    print("O terceiro número é o maior número ímpar")
if resto_a == 0 and resto_b == 0 and resto_c == 0:
    print("Todos os números são pares")

## Questão 7
a = int(input("Entre com o ano"))
if a % 4 == 0 and a % 100 != 0:
    print("O ano é bissexto")
else:
    print("O ano não é bissexto")
    
## Questão 8 não soube fazer :(
